# %%
import pandas as pd

data = pd.read_csv("../../../../Downloads/CDPH_Environmental_Complaints.csv")
data.head()
# Out:
#   COMPLAINT ID                         COMPLAINT TYPE  \
# 0     DOECOMP2                        Noise Complaint
# 1    DOECOMP73                        Noise Complaint
# 2    DOECOMP90                    Asbestos Work Order
# 3    DOECOMP80  Toxics Hazardous Materials Work Order
# 4   DOECOMP236             Illegal Dumping Work Order
#
#                                  ADDRESS  STREET NUMBER FROM  \
# 0              1 S STATE ST, CHICAGO, IL                 1.0
# 1            10 S WACKER DR, CHICAGO, IL                10.0
# 2             100 E OHIO ST, CHICAGO, IL               100.0
# 3            10 S WACKER DR, CHICAGO, IL                10.0
# 4  10000 S STONY ISLAND AVE, CHICAGO, IL             10000.0
#
#    STREET NUMBER TO DIRECTION   STREET NAME STREET TYPE INSPECTOR  \
# 0               NaN         S         STATE          ST        10
# 1               NaN         S        WACKER          DR        25
# 2               NaN         E          OHIO          ST        13
# ...
